# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/Analise_Exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Exploratória — Países Emergentes
# Execute as 3 células abaixo em sequência.

# %%
# 1. Setup
# !pip install -q pandas matplotlib seaborn openpyxl

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if not os.path.exists(REPO):
    # !git clone https://github.com/ottrindade1963/{REPO}.git
# %cd {REPO}
sys.path.insert(0, ".")
# Out:
# Cloning into 'EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO'...
# remote: Enumerating objects: 162, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 162 (delta 33), reused 11 (delta 11), pack-reused 113 (from 1)
# Receiving objects: 100% (162/162), 684.79 KiB | 24.46 MiB/s, done.
# Resolving deltas: 100% (63/63), done.
# /content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO

# %%
# 2. Executar análise exploratória completa
from eda_pipeline import executar_eda
executar_eda()
# Out:
# ==================================================
#   ANÁLISE EXPLORATÓRIA — PAÍSES EMERGENTES
# ==================================================
# ✅ Dados carregados: 3668 linhas x 11 colunas
#
# 📋 RESUMO GERAL
#   Período: 1996 – 2023
#   Países: 131
#   Registros: 3668
#
# 📊 VALORES AUSENTES (%):
# pib_per_capita_ppc                              5.5
# formacao_bruta_capital_fixo_percent_pib        21.6
# matricula_ensino_secundario_percent            37.4
# comercio_percent_pib                           17.4
# investimento_estrangeiro_direto_percent_pib     5.6
# populacao_total                                 0.0
# emprego_industria_percent_emprego_total         5.5
# valor_agregado_industrial_percent_pib           7.5
#
# 📈 ESTATÍSTICAS DESCRITIVAS:
#        pib_per_capita_ppc  formacao_bruta_capital_fixo_percent_pib  \
# count             3465.00                                  2874.00
# mean              8630.65                                    22.56
# std               6717.94                                     8.71
# min                562.86                                    -2.42
# 25%               3227.12                                    17.15
# 50%               6427.31                                    21.70
# 75%              12803.88                                    26.84
# max              39994.62                                    78.00
#
#        matricula_ensino_secundario_percent  comercio_percent_pib  \
# count                              2295.00               3029.00
# mean                                 67.09                 73.72
# std                                  27.04                 35.03
# min                                   3.35                  0.03
# 25%                                  44.29                 47.01
# 50%                                  73.57                 68.63
# 75%                                  88.57                 94.18
# max                                 134.67                347.72
#
#        investimento_estrangeiro_direto_percent_pib  populacao_total  \
# count                                      3464.00     3.668000e+03
# mean                                          3.88     4.305123e+07
# std                                           6.87     1.600165e+08
# min                                         -82.89     9.342000e+03
# 25%                                           0.94     2.211590e+06
# 50%                                           2.44     9.297515e+06
# 75%                                           4.97     2.721617e+07
# max                                         161.82     1.438070e+09
#
#        emprego_industria_percent_emprego_total  \
# count                                  3468.00
# mean                                     17.52
# std                                       7.60
# min                                       1.67
# 25%                                      11.68
# 50%                                      17.52
# 75%                                      23.04
# max                                      37.38
#
#        valor_agregado_industrial_percent_pib
# count                                3393.00
# mean                                   26.44
# std                                    11.88
# min                                     2.09
# 25%                                    18.42
# 50%                                    24.86
# 75%                                    32.34
# max                                    86.67
# 🔍 1. Mapa de valores ausentes...
#   💾 Salvo: resultados_eda/01_missing_heatmap.png
# 📊 2. Histogramas...
#   💾 Salvo: resultados_eda/02_histogramas.png
# 📦 3. Boxplots...
#   💾 Salvo: resultados_eda/03_boxplots.png
# 🔗 4. Matriz de correlação...
#   💾 Salvo: resultados_eda/04_correlacao.png
# 📈 5. Evolução temporal...
#   💾 Salvo: resultados_eda/05_evolucao_temporal.png
# 🏆 6. Top 10 países...
# /content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/eda_visualizacoes.py:90: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top, y="pais", x="pib_per_capita_ppc", ax=ax, palette="viridis")
#   💾 Salvo: resultados_eda/06_top10_pib.png
# 🔵 7. Scatter PIB vs Indústria...
#   💾 Salvo: resultados_eda/07_scatter_pib_industria.png
# 🎻 8. Violin plot emprego industrial...
# /content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/eda_visualizacoes.py:120: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df2, x="decada",
#   💾 Salvo: resultados_eda/08_violin_emprego.png
# 🔷 9. Pairplot...
#   💾 Salvo: resultados_eda/09_pairplot.png
# 🗺️ 10. Heatmap por país...
#   💾 Salvo: resultados_eda/10_heatmap_paises.png
#
# ==================================================
#   ✅ ANÁLISE CONCLUÍDA — 10 gráficos gerados!
#   📂 Resultados em: resultados_eda/
# ==================================================

# %%
# 3. Ver todos os gráficos
from IPython.display import Image, display
import os

for f in sorted(os.listdir("resultados_eda")):
    if f.endswith(".png"):
        print(f"\n{'='*50}\n  {f}\n{'='*50}")
        display(Image(f"resultados_eda/{f}", width=800))
# Out:
# ==================================================
#   01_missing_heatmap.png
# ==================================================
# ==================================================
#   02_histogramas.png
# ==================================================
# ==================================================
#   03_boxplots.png
# ==================================================
# ==================================================
#   04_correlacao.png
# ==================================================
# ==================================================
#   05_evolucao_temporal.png
# ==================================================
# ==================================================
#   06_top10_pib.png
# ==================================================
# ==================================================
#   07_scatter_pib_industria.png
# ==================================================
# ==================================================
#   08_violin_emprego.png
# ==================================================
# ==================================================
#   09_pairplot.png
# ==================================================
# ==================================================
#   10_heatmap_paises.png
# ==================================================
