# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/EDA_Agregados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/EDA_Agregados.ipynb)
#
# # Análise Exploratória — Datasets Agregados (Quantitativo + Qualitativo)
#
# Analisa individualmente os 3 datasets agregados com:
# - Estatísticas descritivas completas (N, Média, Mediana, Moda, DP, Variância, IQR, Assimetria, Curtose, CV)
# - Intervalos de confiança 95%
# - Testes de normalidade (Shapiro-Wilk, D'Agostino)
# - Correlação cruzada Quantitativo × Qualitativo
# - Estatísticas por década
# - 16 visualizações por dataset (48 gráficos no total)

# %%
# 1. Setup: instalar dependências e clonar repositório
# !pip install -q pandas matplotlib seaborn scipy openpyxl

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if os.path.exists(REPO):
    # !rm -rf {REPO}
# !git clone https://github.com/ottrindade1963/{REPO}.git
# %cd {REPO}
sys.path.insert(0, ".")

# Verificação
print("\n✅ Ficheiros encontrados:")
for f in ['agregado_inner.csv',
          'agregado_left_imputado.csv',
          'agregado_outer_completo.csv']:
    existe = '✅' if os.path.exists(f) else '❌'
    print(f"   {existe} {f}")
# Out:
# Cloning into 'EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 272 (delta 73), reused 11 (delta 11), pack-reused 113 (from 1)
# Receiving objects: 100% (272/272), 4.67 MiB | 12.33 MiB/s, done.
# Resolving deltas: 100% (103/103), done.
# /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO
#
# ✅ Ficheiros encontrados:
#    ✅ agregado_inner.csv
#    ✅ agregado_left_imputado.csv
#    ✅ agregado_outer_completo.csv

# %%
# 2. Executar análise exploratória dos 3 datasets
from eda_agreg_pipeline import executar_eda_agregados
resultados = executar_eda_agregados()
# Out:
# ╔════════════════════════════════════════════════════════════════════╗
# ║  ANÁLISE EXPLORATÓRIA — DATASETS AGREGADOS (QUANT. + QUAL.)       ║
# ╚════════════════════════════════════════════════════════════════════╝
#
# ══════════════════════════════════════════════════════════════════════
#   Método 1 — Inner Join
# ══════════════════════════════════════════════════════════════════════
#   Registros: 3,406
#   Países: 127
#   Período: 1996 - 2023
#   Variáveis: 18 (8 quant. + 7 qual.)
#
#   ── Valores Ausentes (Método 1 — Inner Join) ──
#               Variável  Ausentes % Ausentes
#         PIB per capita        95       2.8%
#   Form. Capital (%PIB)       543      15.9%
#     Matrícula Sec. (%)        67       2.0%
#        Comércio (%PIB)       271       8.0%
#             IDE (%PIB)        34       1.0%
#              População         0       0.0%
#       Emprego Ind. (%)        94       2.8%
# Valor Agr. Ind. (%PIB)       100       2.9%
# ...

# %%
# 3. Visualizar gráficos gerados (Método 1)
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

pasta = 'eda_metodo1_inner'
graficos = sorted([f for f in os.listdir(pasta) if f.endswith('.png')])

print(f"\n{'═' * 60}")
print(f"  GRÁFICOS — MÉTODO 1 (Inner Join)")
print(f"{'═' * 60}")

for g in graficos:
    fig, ax = plt.subplots(figsize=(12, 6))
    img = mpimg.imread(os.path.join(pasta, g))
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(g.replace('.png', '').replace('_', ' ').title(), fontsize=11)
    plt.show()
# Out:
# ════════════════════════════════════════════════════════════
#   GRÁFICOS — MÉTODO 1 (Inner Join)
# ════════════════════════════════════════════════════════════

# %%
# 4. Visualizar gráficos gerados (Método 2)
pasta = 'eda_metodo2_left'
graficos = sorted([f for f in os.listdir(pasta) if f.endswith('.png')])

print(f"\n{'═' * 60}")
print(f"  GRÁFICOS — MÉTODO 2 (Left Join + Imputação)")
print(f"{'═' * 60}")

for g in graficos:
    fig, ax = plt.subplots(figsize=(12, 6))
    img = mpimg.imread(os.path.join(pasta, g))
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(g.replace('.png', '').replace('_', ' ').title(), fontsize=11)
    plt.show()
# Out:
# ════════════════════════════════════════════════════════════
#   GRÁFICOS — MÉTODO 2 (Left Join + Imputação)
# ════════════════════════════════════════════════════════════

# %%
# 5. Visualizar gráficos gerados (Método 3)
pasta = 'eda_metodo3_outer'
graficos = sorted([f for f in os.listdir(pasta) if f.endswith('.png')])

print(f"\n{'═' * 60}")
print(f"  GRÁFICOS — MÉTODO 3 (Outer Join + Fonte)")
print(f"{'═' * 60}")

for g in graficos:
    fig, ax = plt.subplots(figsize=(12, 6))
    img = mpimg.imread(os.path.join(pasta, g))
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(g.replace('.png', '').replace('_', ' ').title(), fontsize=11)
    plt.show()
# Out:
# ════════════════════════════════════════════════════════════
#   GRÁFICOS — MÉTODO 3 (Outer Join + Fonte)
# ════════════════════════════════════════════════════════════
