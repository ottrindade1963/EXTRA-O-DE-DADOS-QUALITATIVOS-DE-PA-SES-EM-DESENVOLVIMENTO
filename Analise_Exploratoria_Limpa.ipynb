# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/Analise_Exploratoria_Limpa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Segunda Análise Exploratória (Dados Limpos)
# Execute as 3 células abaixo em sequência (ou Runtime → Run all).

# %%
# 1. Setup: instalar dependências e clonar repositório
# !pip install -q pandas matplotlib seaborn scipy openpyxl

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if os.path.exists(REPO):
    # !rm -rf {REPO}
# !git clone https://github.com/ottrindade1963/{REPO}.git
os.chdir(REPO)
sys.path.insert(0, os.getcwd())
print(f"✅ Diretório: {os.getcwd()}")
print(f"✅ Ficheiros .py: {[f for f in os.listdir('.') if f.startswith('eda2_')]}")
print(f"✅ Ficheiros .csv: {[f for f in os.listdir('.') if 'limpo' in f]}")
# Out:
# Cloning into 'EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 201 (delta 47), reused 11 (delta 11), pack-reused 113 (from 1)
# Receiving objects: 100% (201/201), 3.11 MiB | 15.90 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# ✅ Diretório: /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO
# ✅ Ficheiros .py: ['eda2_visualizacoes.py', 'eda2_loader.py', 'eda2_pipeline.py', 'eda2_config.py']
# ✅ Ficheiros .csv: ['wdi_emergentes_limpo.csv', 'wdi_emergentes_limpo.xlsx']

# %%
# 2. Executar segunda análise exploratória
from eda2_pipeline import executar_eda2
df, df_stats, df_ic, df_testes, corr_matrix = executar_eda2()
# Out:
# ...
#   SEGUNDA ANÁLISE EXPLORATÓRIA
#   Dados Limpos — Países Emergentes
# ...
# ✅ Dados limpos carregados: 3,420 linhas x 11 colunas
#    Período: 1996-2023
#    Países: 127
#
# ...
#   📊 RESUMO GERAL DOS DADOS
# ...
#
#   Total de registros: 3,420
#   Total de colunas: 11
#   Período: 1996-2023
#   Países: 127
#   Anos: 28
#
#   Valores ausentes (missing):
#     PIB per capita (PPC): 95 (2.8%)
#     Form. Bruta Capital (%PIB): 543 (15.9%)
#     Matrícula Secundário (%): 67 (2.0%)
#     Comércio (%PIB): 271 (7.9%)
#     IDE (%PIB): 34 (1.0%)
#     População Total: 0 (0.0%)
#     Emprego Indústria (%): 94 (2.7%)
#     Valor Agregado Ind. (%PIB): 100 (2.9%)
#
# ...
#   📈 ESTATÍSTICAS DESCRITIVAS COMPLETAS
# ...
#
#                    Variável    N        Média      Mediana          Moda  Desvio-Padrão    Variância       Mínimo           Q1           Q3       Máximo          IQR    Amplitude  Assimetria   Curtose      CV(%)
# ...

# %%
# 3. Exibir resultados e gráficos
import matplotlib.pyplot as plt
from PIL import Image
import os

print("\n" + "="*60)
print("  📊 VISUALIZAÇÕES GERADAS")
print("="*60)

graficos = sorted([f for f in os.listdir('resultados_eda2') if f.endswith('.png')])

for grafico in graficos:
    print(f"\n  {grafico}")
    img = Image.open(f'resultados_eda2/{grafico}')
    plt.figure(figsize=(14, 8))
    plt.imshow(img)
    plt.axis('off')
    plt.tight_layout()
    plt.show()

print("\n" + "="*60)
print("  ✅ ANÁLISE CONCLUÍDA COM SUCESSO!")
print("="*60)
# Out:
# ...
#   📊 VISUALIZAÇÕES GERADAS
# ...
#
#   01_heatmap_missing.png
#   02_histogramas.png
#   03_boxplots.png
#   04_matriz_correlacao.png
#   05_evolucao_temporal.png
#   06_top10_paises.png
#   07_scatter_pib_industrializacao.png
#   08_violin_emprego.png
#   09_pairplot.png
#   10_heatmap_paises.png
# ...
#   ✅ ANÁLISE CONCLUÍDA COM SUCESSO!
# ...
