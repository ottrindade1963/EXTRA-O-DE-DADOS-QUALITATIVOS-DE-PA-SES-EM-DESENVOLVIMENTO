# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/Analise_Exploratoria_Qualitativa.ipynb)
#
# # Análise Exploratória — Indicadores de Governança (WGI + ICRG)
#
# **Dataset:** `dados_qualitativos.csv` (gerado pela extração WGI + ICRG)
#
# **Análises:** Estatísticas descritivas, intervalos de confiança, testes de normalidade, classificação de governança, correlações (Pearson + Spearman), 12 visualizações.

# %%
# 1. Setup: instalar dependências e clonar repositório
# !pip install -q pandas matplotlib seaborn openpyxl scipy

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if os.path.exists(REPO):
    # !rm -rf {REPO}
# !git clone https://github.com/ottrindade1963/{REPO}.git
# %cd {REPO}
sys.path.insert(0, ".")

# Verificação
print("\n✅ Ficheiros encontrados:")
for f in sorted(os.listdir('.')):
    if f.endswith(('.py', '.csv')):
        print(f"   {f}")

# %%
# 2. Executar análise exploratória qualitativa completa
from eda_quali_pipeline import executar_eda_qualitativa
df = executar_eda_qualitativa()

# %%
# 3. Exibir todos os gráficos gerados
import os
from IPython.display import Image, display

pasta = 'resultados_eda_quali'
graficos = sorted([f for f in os.listdir(pasta) if f.endswith('.png')])

print(f"📊 {len(graficos)} gráficos gerados:\n")
for g in graficos:
    print(f"── {g} ──")
    display(Image(filename=os.path.join(pasta, g), width=800))
    print()
