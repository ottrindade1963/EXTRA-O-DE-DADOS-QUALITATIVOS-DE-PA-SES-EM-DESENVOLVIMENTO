# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/colab/Passo4_Treinamento_Modelos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Passo 4: Preparação Específica e Treinamento dos Modelos
#
# Este notebook executa o pipeline modularizado para treinar os modelos preditivos (Random Forest, XGBoost, SARIMAX) utilizando os datasets gerados no Passo 3 (Engenharia de Features).

# %%
# 1. Clonar o repositório GitHub
# !rm -rf /content/Analise-industrial-emergentes-Orfeu
# !git clone https://github.com/ottrindade1963/Analise-industrial-emergentes-Orfeu.git
# %cd Analise-industrial-emergentes-Orfeu

# !git clone https://github.com/ottrindade1963/Analise-industrial-emergentes-Orfeu.git
# %cd Analise-industrial-emergentes-Orfeu
# Out:
# Cloning into 'Analise-industrial-emergentes-Orfeu'...
# remote: Enumerating objects: 319, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 319 (delta 79), reused 2 (delta 2), pack-reused 170 (from 1)
# Receiving objects: 100% (319/319), 26.29 MiB | 10.91 MiB/s, done.
# Resolving deltas: 100% (143/143), done.
# /content/Analise-industrial-emergentes-Orfeu
# Cloning into 'Analise-industrial-emergentes-Orfeu'...
# remote: Enumerating objects: 319, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 319 (delta 79), reused 2 (delta 2), pack-reused 170 (from 1)
# Receiving objects: 100% (319/319), 26.29 MiB | 28.67 MiB/s, done.
# Resolving deltas: 100% (143/143), done.
# /content/Analise-industrial-emergentes-Orfeu/Analise-industrial-emergentes-Orfeu

# %%
# 2. Instalar dependências necessárias
# !pip install pandas numpy scikit-learn xgboost statsmodels matplotlib seaborn joblib

# %%
# 3. Executar o pipeline de Treinamento de Modelos
# !python passo4_model_train_pipeline.py
# Out:
# ...
# INICIANDO PIPELINE DE TREINAMENTO DE MODELOS (PASSO 4)
# ...
#
# [1/2] Treinando Modelos...
#
# ...
# Treinando modelos para: nao_agregado - A1_Direta
# ...
#   DEBUG: Colunas do dataset: ['pais', 'codigo_iso3', 'ano', 'pib_per_capita_ppc', 'formacao_bruta_capital_fixo_percent_pib', 'matricula_ensino_secundario_percent', 'comercio_percent_pib', 'investimento_estrangeiro_direto_percent_pib', 'populacao_total', 'emprego_industria_percent_emprego_total', 'valor_agregado_industrial_percent_pib']
#   DEBUG: Colunas object/string encontradas: ['pais', 'codigo_iso3']
#   DEBUG: Colunas a remover (total): ['codigo_iso3', 'ano', 'fonte_dados', 'country', 'country_code', 'pais']
#   DEBUG: Features usadas para treinamento: ['pib_per_capita_ppc', 'formacao_bruta_capital_fixo_percent_pib', 'matricula_ensino_secundario_percent', 'comercio_percent_pib', 'investimento_estrangeiro_direto_percent_pib', 'populacao_total', 'emprego_industria_percent_emprego_total']
# ...

# %%
# 4. Visualizar os resultados gerados
import os
from IPython.display import Image, display

viz_dir = 'modelos_treinados/visualizacoes_treino'
if os.path.exists(viz_dir):
    for filename in os.listdir(viz_dir):
        if filename.endswith('.png'):
            print(f"\n--- {filename} ---")
            display(Image(filename=os.path.join(viz_dir, filename)))
else:
    print("Diretório de visualizações não encontrado.")
# Out:
# Diretório de visualizações não encontrado.
