# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/Treino_Avaliacao_Modelos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/Treino_Avaliacao_Modelos.ipynb)
#
# # Treino e Avaliação de Modelos
#
# Treina e avalia 5 modelos nos 3 datasets agregados:
# - **LSTM** — Rede neural recorrente com memória de longo prazo
# - **Random Forest** — Ensemble de árvores de decisão
# - **XGBoost** — Gradient boosting otimizado
# - **SARIMAX** — Modelo sazonal autorregressivo com exógenas
# - **TFT** — Transformer temporal (GRU + Attention)

# %%
# 1. Setup — Instalar dependências e clonar repositório
# !pip install -q pandas numpy scikit-learn scipy statsmodels xgboost tensorflow openpyxl

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if os.path.exists(REPO):
    # !rm -rf {REPO}
# !git clone https://github.com/ottrindade1963/{REPO}.git
# %cd {REPO}
sys.path.insert(0, ".")

# Verificar dados preparados na raiz
print("\n✓ Verificando dados preparados na raiz...\n")
datasets = ['inner', 'left', 'outer']
for ds in datasets:
    # Verificar ficheiro base de cada dataset
    f_teste = f"{ds}_trees_treino.csv"
    if os.path.exists(f_teste):
        print(f"✅ Dataset {ds.upper()}: Ficheiros encontrados na raiz")
    else:
        print(f"❌ Dataset {ds.upper()}: Ficheiro {f_teste} NÃO encontrado na raiz")
        print(f"   → Verifique se os ficheiros foram carregados para a raiz do repositório.")
# Out:
# Cloning into 'EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO'...
# remote: Enumerating objects: 353, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 353 (delta 63), reused 24 (delta 24), pack-reused 278 (from 2)
# Receiving objects: 100% (353/353), 12.26 MiB | 19.46 MiB/s, done.
# Resolving deltas: 100% (136/136), done.
# /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO
#
# ✓ Verificando dados preparados na raiz...
#
# ✅ Dataset INNER: Ficheiros encontrados na raiz
# ✅ Dataset LEFT: Ficheiros encontrados na raiz
# ✅ Dataset OUTER: Ficheiros encontrados na raiz

# %%
# 2. Treinar e avaliar todos os modelos
from model_pipeline import executar_treino_avaliacao
resultados, tabelas = executar_treino_avaliacao()
# Out:
# ╔════════════════════════════════════════════════════════════════════╗
# ║  TREINO E AVALIAÇÃO — 5 MODELOS × 3 DATASETS                     ║
# ╚════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════╗
# ║  TREINO E AVALIAÇÃO:                     INNER                      ║
# ╚════════════════════════════════════════════════════════════════════╝
#
#   ── Random Forest ──
#     Treino: (2475, 107) | Teste: (706, 107)
#     ✅ Modelo treinado (200 árvores)
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │     263.2445 │
#     │ RMSE         │     593.9615 │
#     │ R2           │       0.9938 │
#     │ MAPE (%)     │         2.23 │
#     │ SMAPE (%)    │         2.18 │
#     ─────────────────────────────────────────────
#
#     Top 10 Features:
#       pib_per_capita_ppc_ma3                   0.9705
#       pib_per_capita_ppc_lag1                  0.0227
#       pib_per_capita_ppc_diff1                 0.0019
#       valor_agregado_industrial_percent_pib_la 0.0004
#       emprego_industria_percent_emprego_total_ 0.0004
#       valor_agregado_industrial_percent_pib_ma 0.0003
#       valor_agregado_industrial_percent_pib_ma 0.0003
#       populacao_total_lag3                     0.0002
#       emprego_industria_percent_emprego_total_ 0.0002
#       valor_agregado_industrial_percent_pib    0.0002
#
#   ── XGBoost ──
#     Treino: (2475, 107) | Teste: (706, 107)
#     ✅ Modelo treinado (300 boosters)
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │     235.7633 │
#     │ RMSE         │     556.4725 │
#     │ R2           │       0.9946 │
#     │ MAPE (%)     │         1.85 │
#     │ SMAPE (%)    │         1.82 │
#     ─────────────────────────────────────────────
#
#     Top 10 Features:
#       pib_per_capita_ppc_ma3                   0.8533
#       pib_per_capita_ppc_lag1                  0.0964
#       pib_per_capita_ppc_ma5                   0.0174
#       wgi_regulatory_quality_ma5               0.0083
#       emprego_industria_percent_emprego_total_ 0.0037
#       emprego_industria_percent_emprego_total_ 0.0035
#       matricula_ensino_secundario_percent_ma5  0.0019
#       wgi_regulatory_quality_lag2              0.0013
#       valor_agregado_industrial_percent_pib    0.0012
#       wgi_regulatory_quality                   0.0011
#
#   ── LSTM ──
#     Treino: (2140, 5, 15) | Teste: (535, 5, 15)
#     Arquitetura: LSTM(64) → LSTM(32) → Dense(16) → Dense(1)
#     ✅ Treinado em 60 épocas (early stopping)
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │       0.0148 │
#     │ RMSE         │        0.022 │
#     │ R2           │       0.9803 │
#     │ MAPE (%)     │         9.75 │
#     │ SMAPE (%)    │         9.28 │
#     ─────────────────────────────────────────────
#
#   ── SARIMAX ──
#     Treino: (2652, 21) | Teste: (727, 21)
#     Exógenas: 14 variáveis
#     Treinando para 10 países (de 127 total)...
#     ✅ Concluído: 10 países OK, 0 falhas
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │     949.5309 │
#     │ RMSE         │     1726.142 │
#     │ R2           │       0.9592 │
#     │ MAPE (%)     │         9.18 │
#     │ SMAPE (%)    │         8.54 │
#     ─────────────────────────────────────────────
#
#   ── Temporal Fusion Transformer ──
#     ⚠️ pytorch-forecasting não disponível
#     → Usando GRU + Attention (arquitetura equivalente)
#     ✅ GRU+Attention treinado em 50 épocas
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │       0.4927 │
#     │ RMSE         │       0.6843 │
#     │ R2           │       0.6867 │
#     │ MAPE (%)     │        84.76 │
#     │ SMAPE (%)    │        67.21 │
#     ─────────────────────────────────────────────
#
#   ── TABELA COMPARATIVA (inner) ──
#               modelo       MAE       RMSE      R2  MAPE (%)  SMAPE (%)  N_amostras
# Rank
# 1               LSTM    0.0148     0.0220  0.9803      9.75       9.28         535
# 2     TFT (GRU+Attn)    0.4927     0.6843  0.6867     84.76      67.21          93
# 3            XGBoost  235.7633   556.4725  0.9946      1.85       1.82         706
# 4      Random Forest  263.2445   593.9615  0.9938      2.23       2.18         706
# 5            SARIMAX  949.5309  1726.1420  0.9592      9.18       8.54          58
#     ✅ 4 gráficos gerados em /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/resultados_modelos/inner/
#
# ╔════════════════════════════════════════════════════════════════════╗
# ║  TREINO E AVALIAÇÃO:                      LEFT                      ║
# ╚════════════════════════════════════════════════════════════════════╝
#
#   ── Random Forest ──
#     Treino: (2563, 107) | Teste: (730, 107)
#     ✅ Modelo treinado (200 árvores)
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │     266.3197 │
#     │ RMSE         │     613.8555 │
#     │ R2           │       0.9934 │
#     │ MAPE (%)     │         2.19 │
#     │ SMAPE (%)    │         2.14 │
#     ─────────────────────────────────────────────
#
#     Top 10 Features:
#       pib_per_capita_ppc_ma3                   0.9637
#       pib_per_capita_ppc_lag1                  0.0294
#       pib_per_capita_ppc_diff1                 0.0018
#       valor_agregado_industrial_percent_pib    0.0006
#       valor_agregado_industrial_percent_pib_la 0.0005
#       valor_agregado_industrial_percent_pib_ma 0.0003
#       valor_agregado_industrial_percent_pib_ma 0.0003
#       emprego_industria_percent_emprego_total_ 0.0003
#       pib_per_capita_ppc_lag2                  0.0002
#       valor_agregado_industrial_percent_pib_la 0.0002
#
#   ── XGBoost ──
#     Treino: (2563, 107) | Teste: (730, 107)
#     ✅ Modelo treinado (300 boosters)
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │     218.1351 │
#     │ RMSE         │     520.6893 │
#     │ R2           │       0.9952 │
#     │ MAPE (%)     │         1.71 │
#     │ SMAPE (%)    │         1.68 │
#     ─────────────────────────────────────────────
#
#     Top 10 Features:
#       pib_per_capita_ppc_ma3                   0.8286
#       pib_per_capita_ppc_lag1                  0.1260
#       pib_per_capita_ppc_ma5                   0.0172
#       wgi_regulatory_quality_ma5               0.0056
#       emprego_industria_percent_emprego_total_ 0.0030
#       emprego_industria_percent_emprego_total_ 0.0027
#       valor_agregado_industrial_percent_pib_la 0.0024
#       valor_agregado_industrial_percent_pib    0.0013
#       pib_per_capita_ppc_diff1                 0.0011
#       emprego_industria_percent_emprego_total_ 0.0010
#
#   ── LSTM ──
#     Treino: (2229, 5, 15) | Teste: (558, 5, 15)
#     Arquitetura: LSTM(64) → LSTM(32) → Dense(16) → Dense(1)
#     ✅ Treinado em 99 épocas (early stopping)
# WARNING:tensorflow:5 out of the last 21 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79f933b30400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │       0.0129 │
#     │ RMSE         │       0.0197 │
#     │ R2           │       0.9844 │
#     │ MAPE (%)     │         8.43 │
#     │ SMAPE (%)    │         7.96 │
#     ─────────────────────────────────────────────
#
#   ── SARIMAX ──
#     Treino: (2705, 21) | Teste: (739, 21)
#     Exógenas: 14 variáveis
#     Treinando para 10 países (de 127 total)...
#     ✅ Concluído: 10 países OK, 0 falhas
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │     952.0971 │
#     │ RMSE         │    1726.6273 │
#     │ R2           │       0.9592 │
#     │ MAPE (%)     │         9.21 │
#     │ SMAPE (%)    │         8.57 │
#     ─────────────────────────────────────────────
#
#   ── Temporal Fusion Transformer ──
#     ⚠️ pytorch-forecasting não disponível
#     → Usando GRU + Attention (arquitetura equivalente)
#     ✅ GRU+Attention treinado em 39 épocas
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │       0.5137 │
#     │ RMSE         │       0.7152 │
#     │ R2           │       0.6522 │
#     │ MAPE (%)     │       106.59 │
#     │ SMAPE (%)    │        76.78 │
#     ─────────────────────────────────────────────
#
#   ── TABELA COMPARATIVA (left) ──
#               modelo       MAE       RMSE      R2  MAPE (%)  SMAPE (%)  N_amostras
# Rank
# 1               LSTM    0.0129     0.0197  0.9844      8.43       7.96         558
# 2     TFT (GRU+Attn)    0.5137     0.7152  0.6522    106.59      76.78         111
# 3            XGBoost  218.1351   520.6893  0.9952      1.71       1.68         730
# 4      Random Forest  266.3197   613.8555  0.9934      2.19       2.14         730
# 5            SARIMAX  952.0971  1726.6273  0.9592      9.21       8.57          58
#     ✅ 4 gráficos gerados em /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/resultados_modelos/left/
#
# ╔════════════════════════════════════════════════════════════════════╗
# ║  TREINO E AVALIAÇÃO:                     OUTER                      ║
# ╚════════════════════════════════════════════════════════════════════╝
#
#   ── Random Forest ──
#     Treino: (2486, 107) | Teste: (709, 107)
#     ✅ Modelo treinado (200 árvores)
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │     265.3899 │
#     │ RMSE         │     598.1053 │
#     │ R2           │       0.9938 │
#     │ MAPE (%)     │          2.2 │
#     │ SMAPE (%)    │         2.15 │
#     ─────────────────────────────────────────────
#
#     Top 10 Features:
#       pib_per_capita_ppc_ma3                   0.9675
#       pib_per_capita_ppc_lag1                  0.0256
#       pib_per_capita_ppc_diff1                 0.0019
#       populacao_total_lag3                     0.0003
#       valor_agregado_industrial_percent_pib    0.0003
#       emprego_industria_percent_emprego_total_ 0.0003
#       valor_agregado_industrial_percent_pib_ma 0.0003
#       valor_agregado_industrial_percent_pib_la 0.0003
#       pib_per_capita_ppc_ma5                   0.0002
#       valor_agregado_industrial_percent_pib_ma 0.0002
#
#   ── XGBoost ──
#     Treino: (2486, 107) | Teste: (709, 107)
#     ✅ Modelo treinado (300 boosters)
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │      226.756 │
#     │ RMSE         │     543.9407 │
#     │ R2           │       0.9948 │
#     │ MAPE (%)     │         1.76 │
#     │ SMAPE (%)    │         1.74 │
#     ─────────────────────────────────────────────
#
#     Top 10 Features:
#       pib_per_capita_ppc_ma3                   0.8550
#       pib_per_capita_ppc_lag1                  0.0774
#       pib_per_capita_ppc_ma5                   0.0317
#       wgi_regulatory_quality_ma5               0.0134
#       emprego_industria_percent_emprego_total_ 0.0032
#       emprego_industria_percent_emprego_total_ 0.0027
#       matricula_ensino_secundario_percent_ma5  0.0019
#       wgi_regulatory_quality_lag2              0.0015
#       valor_agregado_industrial_percent_pib    0.0011
#       pib_per_capita_ppc_diff1                 0.0011
#
#   ── LSTM ──
#     Treino: (2151, 5, 15) | Teste: (538, 5, 15)
#     Arquitetura: LSTM(64) → LSTM(32) → Dense(16) → Dense(1)
#     ✅ Treinado em 69 épocas (early stopping)
# WARNING:tensorflow:5 out of the last 23 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79f92ae6ea20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │        0.014 │
#     │ RMSE         │       0.0208 │
#     │ R2           │       0.9825 │
#     │ MAPE (%)     │        10.03 │
#     │ SMAPE (%)    │        10.19 │
#     ─────────────────────────────────────────────
#
#   ── SARIMAX ──
#     Treino: (2659, 22) | Teste: (728, 22)
#     Exógenas: 14 variáveis
#     Treinando para 10 países (de 127 total)...
#     ✅ Concluído: 10 países OK, 0 falhas
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │     949.5309 │
#     │ RMSE         │     1726.142 │
#     │ R2           │       0.9592 │
#     │ MAPE (%)     │         9.18 │
#     │ SMAPE (%)    │         8.54 │
#     ─────────────────────────────────────────────
#
#   ── Temporal Fusion Transformer ──
#     ⚠️ pytorch-forecasting não disponível
#     → Usando GRU + Attention (arquitetura equivalente)
#     ✅ GRU+Attention treinado em 40 épocas
#     ─────────────────────────────────────────────
#     │ Métrica      │        Valor │
#     ─────────────────────────────────────────────
#     │ MAE          │       0.5168 │
#     │ RMSE         │       0.7182 │
#     │ R2           │       0.6611 │
#     │ MAPE (%)     │         98.5 │
#     │ SMAPE (%)    │        74.65 │
#     ─────────────────────────────────────────────
#
#   ── TABELA COMPARATIVA (outer) ──
#               modelo       MAE       RMSE      R2  MAPE (%)  SMAPE (%)  N_amostras
# Rank
# 1               LSTM    0.0140     0.0208  0.9825     10.03      10.19         538
# 2     TFT (GRU+Attn)    0.5168     0.7182  0.6611     98.50      74.65          95
# 3            XGBoost  226.7560   543.9407  0.9948      1.76       1.74         709
# 4      Random Forest  265.3899   598.1053  0.9938      2.20       2.15         709
# 5            SARIMAX  949.5309  1726.1420  0.9592      9.18       8.54          58
#     ✅ 4 gráficos gerados em /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/resultados_modelos/outer/
#
# ══════════════════════════════════════════════════════════════════════
#   ✅ TREINO E AVALIAÇÃO COMPLETOS
# ══════════════════════════════════════════════════════════════════════
#
#   INNER:
#     🏆 Melhor modelo: LSTM
#        RMSE=0.0220 | R²=0.9803 | MAPE=9.75%
#
#   LEFT:
#     🏆 Melhor modelo: LSTM
#        RMSE=0.0197 | R²=0.9844 | MAPE=8.43%
#
#   OUTER:
#     🏆 Melhor modelo: LSTM
#        RMSE=0.0208 | R²=0.9825 | MAPE=10.03%
#
# ══════════════════════════════════════════════════════════════════════

# %%
# 3. Visualizar resultados
import os
from IPython.display import Image, display

for dataset in ['inner', 'left', 'outer']:
    pasta = f'resultados_modelos/{dataset}'
    if os.path.exists(pasta):
        print(f"\n{'═' * 60}")
        print(f"  RESULTADOS: {dataset.upper()}")
        print(f"{'═' * 60}")
        for img in sorted(os.listdir(pasta)):
            if img.endswith('.png'):
                print(f"\n  {img}")
                display(Image(os.path.join(pasta, img), width=800))
# Out:
# ════════════════════════════════════════════════════════════
#   RESULTADOS: INNER
# ════════════════════════════════════════════════════════════
#
#   01_real_vs_previsto.png
#   02_comparacao_metricas.png
#   03_distribuicao_residuos.png
#   04_ranking_modelos.png
# ════════════════════════════════════════════════════════════
#   RESULTADOS: LEFT
# ════════════════════════════════════════════════════════════
#
#   01_real_vs_previsto.png
#   02_comparacao_metricas.png
#   03_distribuicao_residuos.png
#   04_ranking_modelos.png
# ════════════════════════════════════════════════════════════
#   RESULTADOS: OUTER
# ════════════════════════════════════════════════════════════
#
#   01_real_vs_previsto.png
#   02_comparacao_metricas.png
#   03_distribuicao_residuos.png
#   04_ranking_modelos.png

# %%
# 4. Tabelas comparativas finais
import pandas as pd

for dataset, tabela in tabelas.items():
    print(f"\n{'═' * 60}")
    print(f"  RANKING — {dataset.upper()}")
    print(f"{'═' * 60}")
    display(tabela)
# Out:
# ════════════════════════════════════════════════════════════
#   RANKING — INNER
# ════════════════════════════════════════════════════════════
#               modelo       MAE       RMSE      R2  MAPE (%)  SMAPE (%)  \
# Rank
# 1               LSTM    0.0148     0.0220  0.9803      9.75       9.28
# 2     TFT (GRU+Attn)    0.4927     0.6843  0.6867     84.76      67.21
# 3            XGBoost  235.7633   556.4725  0.9946      1.85       1.82
# 4      Random Forest  263.2445   593.9615  0.9938      2.23       2.18
# 5            SARIMAX  949.5309  1726.1420  0.9592      9.18       8.54
#
#       N_amostras
# Rank
# 1            535
# 2             93
# 3            706
# 4            706
# 5             58
# ════════════════════════════════════════════════════════════
#   RANKING — LEFT
# ════════════════════════════════════════════════════════════
#               modelo       MAE       RMSE      R2  MAPE (%)  SMAPE (%)  \
# Rank
# 1               LSTM    0.0129     0.0197  0.9844      8.43       7.96
# 2     TFT (GRU+Attn)    0.5137     0.7152  0.6522    106.59      76.78
# 3            XGBoost  218.1351   520.6893  0.9952      1.71       1.68
# 4      Random Forest  266.3197   613.8555  0.9934      2.19       2.14
# 5            SARIMAX  952.0971  1726.6273  0.9592      9.21       8.57
#
#       N_amostras
# Rank
# 1            558
# 2            111
# 3            730
# 4            730
# 5             58
# ════════════════════════════════════════════════════════════
#   RANKING — OUTER
# ════════════════════════════════════════════════════════════
#               modelo       MAE       RMSE      R2  MAPE (%)  SMAPE (%)  \
# Rank
# 1               LSTM    0.0140     0.0208  0.9825     10.03      10.19
# 2     TFT (GRU+Attn)    0.5168     0.7182  0.6611     98.50      74.65
# 3            XGBoost  226.7560   543.9407  0.9948      1.76       1.74
# 4      Random Forest  265.3899   598.1053  0.9938      2.20       2.15
# 5            SARIMAX  949.5309  1726.1420  0.9592      9.18       8.54
#
#       N_amostras
# Rank
# 1            538
# 2             95
# 3            709
# 4            709
# 5             58
