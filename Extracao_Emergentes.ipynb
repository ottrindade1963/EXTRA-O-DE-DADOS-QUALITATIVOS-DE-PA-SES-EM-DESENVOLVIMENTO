# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/Extracao_Emergentes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extração de Dados WDI — Países Emergentes
# Execute as células abaixo em sequência.

# %%
# 1. Setup: instalar dependências e clonar repositório
# !pip install -q pandas requests openpyxl

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if not os.path.exists(REPO):
    # !git clone https://github.com/ottrindade1963/{REPO}.git
sys.path.insert(0, REPO)
# Out:
# Cloning into 'EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 80 (delta 29), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (80/80), 44.88 KiB | 1.18 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# 2. Executar extração
from pipeline import executar
executar()
# Out:
# === INICIANDO DOWNLOAD DE DADOS WDI ===
# ✅ 131 países em desenvolvimento identificados.
# -> Baixando: pib_per_capita_ppc...
# -> Baixando: formacao_bruta_capital_fixo_percent_pib...
# -> Baixando: matricula_ensino_secundario_percent...
# -> Baixando: comercio_percent_pib...
# -> Baixando: investimento_estrangeiro_direto_percent_pib...
# -> Baixando: populacao_total...
# -> Baixando: emprego_industria_percent_emprego_total...
# -> Baixando: valor_agregado_industrial_percent_pib...
#
# ✅ Concluído! 3668 registros salvos em 'data/raw/'

# %%
# 3. Ver resultados
import pandas as pd
df = pd.read_csv("data/raw/wdi_emergentes_final.csv")
display(df.head())
# Out:
#           pais codigo_iso3   ano  pib_per_capita_ppc  \
# 0  Afghanistan         AFG  1996                 NaN
# 1  Afghanistan         AFG  1997                 NaN
# 2  Afghanistan         AFG  1998                 NaN
# 3  Afghanistan         AFG  1999                 NaN
# 4  Afghanistan         AFG  2000         1617.826475
#
#    formacao_bruta_capital_fixo_percent_pib  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    matricula_ensino_secundario_percent  comercio_percent_pib  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
#
# ...
