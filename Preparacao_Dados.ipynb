# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/Preparacao_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/Preparacao_Dados.ipynb)
#
# # Preparação de Dados para Modelagem
#
# Prepara os 3 datasets agregados para 5 modelos:
# - **LSTM** — Normalização Min-Max + Sequências 3D
# - **Random Forest / XGBoost** — Lags + Médias Móveis + Diferenças
# - **SARIMAX** — Teste ADF + Diferenciação + Exógenas
# - **TFT** — Z-score + Time Index + Classificação de variáveis

# %%
# 1. Setup
# !pip install -q pandas numpy scikit-learn scipy statsmodels openpyxl

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if os.path.exists(REPO):
    # !rm -rf {REPO}
# !git clone https://github.com/ottrindade1963/{REPO}.git
# %cd {REPO}
sys.path.insert(0, ".")

# Verificação
for f in ['agregado_inner.csv', 'agregado_left_imputado.csv', 'agregado_outer_completo.csv']:
    print(f"{'✅' if os.path.exists(f) else '❌'} {f}")
# Out:
# Cloning into 'EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO'...
# remote: Enumerating objects: 289, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 289 (delta 78), reused 11 (delta 11), pack-reused 113 (from 1)
# Receiving objects: 100% (289/289), 8.98 MiB | 12.06 MiB/s, done.
# Resolving deltas: 100% (108/108), done.
# /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO
# ✅ agregado_inner.csv
# ✅ agregado_left_imputado.csv
# ✅ agregado_outer_completo.csv

# %%
# 2. Executar preparação completa
from prep_pipeline import executar_preparacao
pastas = executar_preparacao()
# Out:
# ╔════════════════════════════════════════════════════════════════════╗
# ║  PREPARAÇÃO DE DADOS PARA MODELAGEM — 5 MODELOS × 3 DATASETS     ║
# ╚════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════╗
# ║  PREPARAÇÃO:                     DATASET INNER                      ║
# ╚════════════════════════════════════════════════════════════════════╝
#
#   ── Etapa Base ──
#     ✅ Carregado: (3406, 18)
#     Removidas 98 linhas com >50% missing
#     ✅ Transformação log aplicada
#
#   ── Preparação para RF/XGBoost (Dataset inner) ──
#     ✅ Lags criados: [1, 2, 3]
#     ✅ Médias móveis: janelas [3, 5]
#     ✅ Diferenças de 1ª ordem criadas
#     ✅ País codificado (label encoding)
#     ✅ Removidas 127 linhas (lags iniciais)
#     RF/XGBoost treino: 2,475 linhas × 111 colunas | Missing: 0
#     RF/XGBoost teste: 706 linhas × 111 colunas | Missing: 0
#
#   ── Preparação para LSTM (Dataset inner) ──
# ...

# %%
# 3. Verificar ficheiros gerados
import os
for chave, pasta in pastas.items():
    print(f"\n{'═' * 50}")
    print(f"  {chave}")
    print(f"{'═' * 50}")
    for f in sorted(os.listdir(pasta)):
        tamanho = os.path.getsize(os.path.join(pasta, f)) / 1024
        print(f"  {f:40s} {tamanho:8.1f} KB")
# Out:
# ══════════════════════════════════════════════════
#   inner
# ══════════════════════════════════════════════════
#   lstm_teste.npz                              318.1 KB
#   lstm_teste_info.csv                           4.7 KB
#   lstm_treino.npz                            1271.1 KB
#   lstm_treino_info.csv                         18.8 KB
#   sarimax_exogenas.csv                          0.4 KB
#   sarimax_teste.csv                           193.2 KB
#   sarimax_treino.csv                          697.0 KB
#   tft_classificacao.csv                         0.6 KB
#   tft_teste.csv                               248.6 KB
#   tft_treino.csv                              910.5 KB
#   trees_teste.csv                            1025.6 KB
#   trees_treino.csv                           3507.0 KB
#
# ══════════════════════════════════════════════════
#   left
# ══════════════════════════════════════════════════
#   lstm_teste.npz                              331.8 KB
# ...
