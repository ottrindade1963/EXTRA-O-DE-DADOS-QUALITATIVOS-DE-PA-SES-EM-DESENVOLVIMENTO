# %% [markdown]
# <a href="https://colab.research.google.com/github/ottrindade1963/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO/blob/main/Extracao_WGI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extração de Indicadores Qualitativos
# ## WGI (Banco Mundial) + ICRG (QoG)
# Execute as 3 células abaixo em sequência (ou Runtime → Run all).

# %%
# 1. Setup: instalar dependências e clonar repositório
# !pip install -q pandas requests openpyxl

import os, sys
REPO = "EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO"
if os.path.exists(REPO):
    # !rm -rf {REPO}
# !git clone https://github.com/ottrindade1963/{REPO}.git
os.chdir(REPO)
sys.path.insert(0, os.getcwd())
print(f"✅ Diretório: {os.getcwd()}")
print(f"✅ Ficheiros .py: {[f for f in os.listdir('.') if f.startswith('wgi_')]}")
# Out:
# Cloning into 'EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO'...
# remote: Enumerating objects: 231, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 231 (delta 57), reused 11 (delta 11), pack-reused 113 (from 1)
# Receiving objects: 100% (231/231), 4.27 MiB | 15.44 MiB/s, done.
# Resolving deltas: 100% (87/87), done.
# ✅ Diretório: /content/EXTRA-O-DE-DADOS-QUALITATIVOS-DE-PA-SES-EM-DESENVOLVIMENTO
# ✅ Ficheiros .py: ['wgi_downloader.py', 'wgi_exporter.py', 'wgi_processor.py', 'wgi_pipeline.py', 'wgi_config.py']

# %%
# 2. Executar download e processamento
from wgi_pipeline import executar_extracao_wgi
df_wgi = executar_extracao_wgi()
# Out:
# ============================================================
#   EXTRAÇÃO DE INDICADORES QUALITATIVOS
#   WGI (Banco Mundial) + ICRG (QoG)
# ============================================================
# 📥 Baixando Worldwide Governance Indicators (WGI)...
#    ✅ WGI baixado com sucesso
#    Abas disponíveis: ['VA', 'PV', 'GE', 'RQ', 'RL', 'CC']
#
# 🔧 Processando WGI...
#    Aba: VA (wgi_voice_accountability)
#      ✅ 4978 linhas
#    Aba: PV (wgi_political_stability)
#      ✅ 5279 linhas
#    Aba: GE (wgi_gov_effectiveness)
#      ✅ 5282 linhas
#    Aba: RQ (wgi_regulatory_quality)
#      ✅ 5279 linhas
#    Aba: RL (wgi_rule_law)
#      ✅ 5284 linhas
#    Aba: CC (wgi_control_corruption)
#      ✅ 5283 linhas
#
#    ✅ WGI processado: 5284 linhas (país-ano)
#
# 📥 Baixando ICRG via QoG Standard Dataset...
#    ✅ QoG baixado com sucesso
#    Dimensões: (12585, 1813)
#
# 🔧 Processando ICRG...
#    ✅ ICRG processado: 5595 linhas (país-ano)
#
# 🔗 Integrando WGI e ICRG...
#    ✅ Dataset integrado: 6020 linhas, 9 colunas
#
# ============================================================
#   💾 EXPORTANDO DADOS
# ============================================================
#
#   ✅ dados_qualitativos/dados_qualitativos.csv
#   ✅ dados_qualitativos/dados_qualitativos.xlsx
#
#   Painel final: 6020 linhas, 9 colunas
#   Países: 214
#   Período: 1996 - 2024
#   📁 Ficheiros salvos em: dados_qualitativos/
#
# ============================================================
#   ✅ EXTRAÇÃO CONCLUÍDA COM SUCESSO!
# ============================================================

# %%
# 3. Visualizar amostra dos dados extraídos
print("\n📊 AMOSTRA DOS DADOS EXTRAÍDOS:")
print(f"\nShape: {df_wgi.shape}")
print(f"Colunas: {df_wgi.columns.tolist()}")
print(f"\nPrimeiras 5 linhas:")
display(df_wgi.head())
print(f"\nÚltimas 5 linhas:")
display(df_wgi.tail())
print(f"\nEstatísticas descritivas:")
display(df_wgi.describe().round(3))
# Out:
# 📊 AMOSTRA DOS DADOS EXTRAÍDOS:
#
# Shape: (6020, 9)
# Colunas: ['country_code', 'year', 'wgi_control_corruption', 'wgi_gov_effectiveness', 'wgi_political_stability', 'wgi_regulatory_quality', 'wgi_rule_law', 'wgi_voice_accountability', 'icrg_qog']
#
# Primeiras 5 linhas:
#   country_code  year  wgi_control_corruption  wgi_gov_effectiveness  \
# 0          ABW  2004                0.777778               0.787879
# 1          ABW  2005                0.875000               0.875000
# 2          ABW  2006                0.875000               0.875000
# 3          ABW  2007                0.875000               0.875000
# 4          ABW  2008                0.875000               0.875000
#
#    wgi_political_stability  wgi_regulatory_quality  wgi_rule_law  \
# 0                 0.858586                0.747475      0.767677
# 1                 0.937500                0.833333      0.812500
# 2                 0.937500                0.833333      0.812500
# 3                 0.937500                0.833333      0.812500
# 4                 0.937500                0.833333      0.812500
#
#    wgi_voice_accountability  icrg_qog
# 0                  0.707071       NaN
# 1                  0.875000       NaN
# 2                  0.875000       NaN
# 3                  0.875000       NaN
# 4                  0.875000       NaN
# Últimas 5 linhas:
#      country_code  year  wgi_control_corruption  wgi_gov_effectiveness  \
# 6015          ZWE  2020                     0.0                    0.0
# 6016          ZWE  2021                     0.0                    0.0
# 6017          ZWE  2022                     0.0                    0.0
# 6018          ZWE  2023                     0.0                    0.0
# 6019          ZWE  2024                     0.0                    0.0
#
#       wgi_political_stability  wgi_regulatory_quality  wgi_rule_law  \
# 6015                    0.125                0.107143         0.125
# 6016                    0.125                0.107143         0.125
# 6017                    0.125                0.107143         0.125
# 6018                    0.125                0.107143         0.100
# 6019                    0.125                0.107143         0.125
#
#       wgi_voice_accountability  icrg_qog
# 6015                  0.105333  0.347222
# 6016                  0.097333  0.347222
# 6017                  0.097333  0.347222
# 6018                  0.101333  0.347222
# 6019                  0.099333  0.349537
# Estatísticas descritivas:
#            year  wgi_control_corruption  wgi_gov_effectiveness  \
# count  6020.000                5283.000               5282.000
# mean   2010.216                   0.385                  0.406
# std       8.314                   0.280                  0.295
# min    1996.000                   0.000                  0.000
# 25%    2003.000                   0.125                  0.250
# 50%    2010.000                   0.375                  0.375
# 75%    2017.000                   0.625                  0.583
# max    2024.000                   1.000                  1.000
#
#        wgi_political_stability  wgi_regulatory_quality  wgi_rule_law  \
# count                 5279.000                5279.000      5284.000
# mean                     0.601                   0.522         0.526
# std                      0.259                   0.232         0.255
# min                      0.000                   0.000         0.000
# 25%                      0.438                   0.357         0.325
# 50%                      0.625                   0.500         0.500
# 75%                      0.812                   0.714         0.750
# max                      1.000                   1.000         1.000
#
#        wgi_voice_accountability  icrg_qog
# count                  4978.000  3991.000
# mean                      0.480     0.543
# std                       0.266     0.206
# min                       0.000     0.056
# 25%                       0.253     0.405
# 50%                       0.468     0.500
# 75%                       0.690     0.667
# max                       1.000     1.000
